# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("../input"))
# Out:
# ['interiordesign-dataset']

# %%
FAST_RUN = False
epochs= 3 if FAST_RUN else 100
IMAGE_WIDTH=224
IMAGE_HEIGHT=224
batch_size=160
earlystop_patience = 25
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
folder_path = r'../input/interiordesign-dataset/v5.0/train/'
folder_path_val = r'../input/interiordesign-dataset/v5.0/val/'
LABELS = os.listdir(folder_path)

# %%
listfolder = os.listdir(folder_path)
listfolder.sort()
print(listfolder)
# Out:
# ['ArtDecor', 'Hitech', 'Indochina', 'Industrial', 'Scandinavian']

# %%
categories = []
filenames = []

for folder in listfolder:
    for item in os.listdir(os.path.join(folder_path, folder)):
        label = item[: item.find('_')]
        filenames.append(label + '/' + item)
        categories.append(label)

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})
print(train_df)
# Out:
#                                  filename      category
# 0             ArtDecor/ArtDecor_01307.jpg      ArtDecor
# 1             ArtDecor/ArtDecor_01555.jpg      ArtDecor
# 2             ArtDecor/ArtDecor_01100.jpg      ArtDecor
# 3             ArtDecor/ArtDecor_00698.jpg      ArtDecor
# 4             ArtDecor/ArtDecor_00899.jpg      ArtDecor
# ...                                   ...           ...
# 7742  Scandinavian/Scandinavian_01058.jpg  Scandinavian
# 7743  Scandinavian/Scandinavian_00438.jpg  Scandinavian
# 7744  Scandinavian/Scandinavian_00684.jpg  Scandinavian
# 7745  Scandinavian/Scandinavian_00671.jpg  Scandinavian
# 7746  Scandinavian/Scandinavian_01434.jpg  Scandinavian
#
# [7747 rows x 2 columns]

# %%
train_df.head()
# Out:
#                       filename  category
# 0  ArtDecor/ArtDecor_01307.jpg  ArtDecor
# 1  ArtDecor/ArtDecor_01555.jpg  ArtDecor
# 2  ArtDecor/ArtDecor_01100.jpg  ArtDecor
# 3  ArtDecor/ArtDecor_00698.jpg  ArtDecor
# 4  ArtDecor/ArtDecor_00899.jpg  ArtDecor

# %%
train_df.tail()
# Out:
#                                  filename      category
# 7742  Scandinavian/Scandinavian_01058.jpg  Scandinavian
# 7743  Scandinavian/Scandinavian_00438.jpg  Scandinavian
# 7744  Scandinavian/Scandinavian_00684.jpg  Scandinavian
# 7745  Scandinavian/Scandinavian_00671.jpg  Scandinavian
# 7746  Scandinavian/Scandinavian_01434.jpg  Scandinavian

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
categories = []
filenames = []

for folder in listfolder:
    for item in os.listdir(os.path.join(folder_path_val, folder)):
        label = item[: item.find('_')]
        filenames.append(label + '/' + item)
        categories.append(label)

validate_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

print(validate_df)
# Out:
#                                  filename      category
# 0             ArtDecor/ArtDecor_00318.jpg      ArtDecor
# 1             ArtDecor/ArtDecor_01178.jpg      ArtDecor
# 2             ArtDecor/ArtDecor_00063.jpg      ArtDecor
# 3             ArtDecor/ArtDecor_00008.jpg      ArtDecor
# 4             ArtDecor/ArtDecor_01431.jpg      ArtDecor
# ...                                   ...           ...
# 1925  Scandinavian/Scandinavian_00715.jpg  Scandinavian
# 1926  Scandinavian/Scandinavian_00341.jpg  Scandinavian
# 1927  Scandinavian/Scandinavian_01256.jpg  Scandinavian
# 1928  Scandinavian/Scandinavian_00014.jpg  Scandinavian
# 1929  Scandinavian/Scandinavian_00660.jpg  Scandinavian
#
# [1930 rows x 2 columns]

# %%
validate_df.head()
# Out:
#                       filename  category
# 0  ArtDecor/ArtDecor_00318.jpg  ArtDecor
# 1  ArtDecor/ArtDecor_01178.jpg  ArtDecor
# 2  ArtDecor/ArtDecor_00063.jpg  ArtDecor
# 3  ArtDecor/ArtDecor_00008.jpg  ArtDecor
# 4  ArtDecor/ArtDecor_01431.jpg  ArtDecor

# %%
validate_df.tail()
# Out:
#                                  filename      category
# 1925  Scandinavian/Scandinavian_00715.jpg  Scandinavian
# 1926  Scandinavian/Scandinavian_00341.jpg  Scandinavian
# 1927  Scandinavian/Scandinavian_01256.jpg  Scandinavian
# 1928  Scandinavian/Scandinavian_00014.jpg  Scandinavian
# 1929  Scandinavian/Scandinavian_00660.jpg  Scandinavian

# %%
sample = random.choice(filenames)
image = load_img(os.path.join(folder_path_val, sample))
print(image)
plt.imshow(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F6C5FBE5A50>

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import cv2
import os
import re
import h5py
import keras
import random
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report,confusion_matrix
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D, GlobalMaxPooling2D
from keras.applications import VGG19, ResNet50, NASNetLarge, DenseNet201, VGG16, InceptionResNetV2, Xception, ResNet152, InceptionV3, DenseNet121
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.optimizers import Adam

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 222, 222, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 109, 109, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 52, 52, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               44302848
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 44,401,605
# Trainable params: 44,400,133
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
# model_base = DenseNet201(input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS),
#                          include_top=False, 
#                          weights=None)

# model = Sequential([
#     model_base,
# #     GlobalMaxPooling2D(),
# #     Dense(512, activation='relu'),
# #     Dropout(0.5),
#     MaxPool2D((2,2) , strides = 2),
#     Flatten(),
#     Dense(5 , activation='softmax')])
    
# # optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# model.summary()

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

earlystop = EarlyStopping(monitor="val_accuracy",
                          patience=earlystop_patience,
                          restore_best_weights=True)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks = [earlystop, learning_rate_reduction]

# %%
# df["category"] = df["category"].replace({0: 'Benign', 1: 'Malignant'})

# %%
# train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_datagen = ImageDataGenerator(
    rotation_range=7,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    folder_path, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 7747 validated image filenames belonging to 5 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    folder_path_val, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 1930 validated image filenames belonging to 5 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    folder_path,
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 48/48 [==============================] - 175s 4s/step - loss: 2.0418 - accuracy: 0.4393 - val_loss: 51.7179 - val_accuracy: 0.2062
# Epoch 2/100
# 48/48 [==============================] - 128s 3s/step - loss: 1.2209 - accuracy: 0.5590 - val_loss: 22.0272 - val_accuracy: 0.2083
# Epoch 3/100
# 48/48 [==============================] - 128s 3s/step - loss: 1.0464 - accuracy: 0.6183 - val_loss: 4.8534 - val_accuracy: 0.1906
# Epoch 4/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.9646 - accuracy: 0.6488 - val_loss: 3.2470 - val_accuracy: 0.1943
# Epoch 5/100
# 48/48 [==============================] - 127s 3s/step - loss: 0.9302 - accuracy: 0.6547 - val_loss: 2.0091 - val_accuracy: 0.2854
# Epoch 6/100
# 48/48 [==============================] - 126s 3s/step - loss: 0.8750 - accuracy: 0.6835 - val_loss: 2.2639 - val_accuracy: 0.3427
# Epoch 7/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.8287 - accuracy: 0.6884 - val_loss: 2.3028 - val_accuracy: 0.3260
# Epoch 8/100
# 48/48 [==============================] - 127s 3s/step - loss: 0.7716 - accuracy: 0.7172 - val_loss: 2.0563 - val_accuracy: 0.3927
# Epoch 9/100
# 48/48 [==============================] - 127s 3s/step - loss: 0.7734 - accuracy: 0.7171 - val_loss: 2.0055 - val_accuracy: 0.4448
# Epoch 10/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.7332 - accuracy: 0.7346 - val_loss: 3.3785 - val_accuracy: 0.3156
# Epoch 11/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.6921 - accuracy: 0.7502 - val_loss: 1.8114 - val_accuracy: 0.4870
# Epoch 12/100
# 48/48 [==============================] - 127s 3s/step - loss: 0.6624 - accuracy: 0.7611 - val_loss: 2.7099 - val_accuracy: 0.3750
# Epoch 13/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.6052 - accuracy: 0.7800 - val_loss: 1.3590 - val_accuracy: 0.5844
# Epoch 14/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.6067 - accuracy: 0.7800 - val_loss: 0.7842 - val_accuracy: 0.7198
# Epoch 15/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.5943 - accuracy: 0.7858 - val_loss: 1.8842 - val_accuracy: 0.4146
# Epoch 16/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.6006 - accuracy: 0.7732 - val_loss: 1.0281 - val_accuracy: 0.6552
# Epoch 17/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.5629 - accuracy: 0.7971 - val_loss: 1.1973 - val_accuracy: 0.6620
# Epoch 18/100
# 48/48 [==============================] - 127s 3s/step - loss: 0.5709 - accuracy: 0.7897 - val_loss: 1.5557 - val_accuracy: 0.5615
# Epoch 19/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.5403 - accuracy: 0.8050 - val_loss: 5.7804 - val_accuracy: 0.4276
# Epoch 20/100
# 48/48 [==============================] - 127s 3s/step - loss: 0.5480 - accuracy: 0.7978 - val_loss: 0.9633 - val_accuracy: 0.6714
# Epoch 21/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.5281 - accuracy: 0.8117 - val_loss: 0.8432 - val_accuracy: 0.7156
# Epoch 22/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.5022 - accuracy: 0.8184 - val_loss: 2.9833 - val_accuracy: 0.4563
# Epoch 23/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.4753 - accuracy: 0.8329 - val_loss: 1.5668 - val_accuracy: 0.5495
# Epoch 24/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.4717 - accuracy: 0.8353 - val_loss: 1.0441 - val_accuracy: 0.6604
# Epoch 25/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.4774 - accuracy: 0.8310 - val_loss: 2.6732 - val_accuracy: 0.4411
# Epoch 26/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.4625 - accuracy: 0.8345 - val_loss: 0.8306 - val_accuracy: 0.7307
# Epoch 27/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.4402 - accuracy: 0.8385 - val_loss: 1.3106 - val_accuracy: 0.6349
# Epoch 28/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.4252 - accuracy: 0.8451 - val_loss: 1.4931 - val_accuracy: 0.6109
# Epoch 29/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.3979 - accuracy: 0.8562 - val_loss: 0.9456 - val_accuracy: 0.7188
# Epoch 30/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.4114 - accuracy: 0.8559 - val_loss: 2.0142 - val_accuracy: 0.5646
# Epoch 31/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.4024 - accuracy: 0.8535 - val_loss: 1.3027 - val_accuracy: 0.6427
# Epoch 32/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.3795 - accuracy: 0.8652 - val_loss: 0.9962 - val_accuracy: 0.7151
# Epoch 33/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.3776 - accuracy: 0.8623 - val_loss: 0.7306 - val_accuracy: 0.7609
# Epoch 34/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.3564 - accuracy: 0.8715 - val_loss: 1.2169 - val_accuracy: 0.7057
# Epoch 35/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.3609 - accuracy: 0.8693 - val_loss: 1.9243 - val_accuracy: 0.6062
# Epoch 36/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.3668 - accuracy: 0.8651 - val_loss: 1.2085 - val_accuracy: 0.6484
# Epoch 37/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.3540 - accuracy: 0.8771 - val_loss: 1.5700 - val_accuracy: 0.7453
# Epoch 38/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.3375 - accuracy: 0.8737 - val_loss: 0.8780 - val_accuracy: 0.7443
# Epoch 39/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.3152 - accuracy: 0.8820 - val_loss: 1.8918 - val_accuracy: 0.5818
# Epoch 40/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.3300 - accuracy: 0.8793 - val_loss: 1.0259 - val_accuracy: 0.6964
# Epoch 41/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.3150 - accuracy: 0.8857 - val_loss: 2.4722 - val_accuracy: 0.4859
# Epoch 42/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.3300 - accuracy: 0.8821 - val_loss: 0.7978 - val_accuracy: 0.7792
# Epoch 43/100
# 48/48 [==============================] - 128s 3s/step - loss: 0.3150 - accuracy: 0.8830 - val_loss: 1.3001 - val_accuracy: 0.6766
# Epoch 44/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.3534 - accuracy: 0.8747 - val_loss: 4.7655 - val_accuracy: 0.5156
# Epoch 45/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.4628 - accuracy: 0.8390 - val_loss: 12.4594 - val_accuracy: 0.4635
# Epoch 46/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.3548 - accuracy: 0.8702 - val_loss: 8.8324 - val_accuracy: 0.4557
# Epoch 47/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.3406 - accuracy: 0.8750 - val_loss: 1.5712 - val_accuracy: 0.6042
# Epoch 48/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.3643 - accuracy: 0.8703 - val_loss: 1.5341 - val_accuracy: 0.6255
# Epoch 49/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.3257 - accuracy: 0.8865 - val_loss: 2.0648 - val_accuracy: 0.5891
# Epoch 50/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2985 - accuracy: 0.8977 - val_loss: 1.1026 - val_accuracy: 0.6875
# Epoch 51/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.2708 - accuracy: 0.9092 - val_loss: 1.1987 - val_accuracy: 0.6953
# Epoch 52/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.2507 - accuracy: 0.9091 - val_loss: 1.1373 - val_accuracy: 0.6833
# Epoch 53/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2737 - accuracy: 0.9040 - val_loss: 2.2361 - val_accuracy: 0.5146
# Epoch 54/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2741 - accuracy: 0.9030 - val_loss: 1.2789 - val_accuracy: 0.6750
# Epoch 55/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.2429 - accuracy: 0.9141 - val_loss: 1.3268 - val_accuracy: 0.6990
# Epoch 56/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2527 - accuracy: 0.9106 - val_loss: 0.6059 - val_accuracy: 0.8026
# Epoch 57/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2280 - accuracy: 0.9202 - val_loss: 1.5660 - val_accuracy: 0.6083
# Epoch 58/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.2229 - accuracy: 0.9261 - val_loss: 0.6679 - val_accuracy: 0.8057
# Epoch 59/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.2369 - accuracy: 0.9139 - val_loss: 1.5582 - val_accuracy: 0.6969
# Epoch 60/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2308 - accuracy: 0.9171 - val_loss: 0.7015 - val_accuracy: 0.7870
# Epoch 61/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2378 - accuracy: 0.9132 - val_loss: 1.6609 - val_accuracy: 0.6755
# Epoch 62/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.2206 - accuracy: 0.9203 - val_loss: 0.7451 - val_accuracy: 0.7943
# Epoch 63/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.2146 - accuracy: 0.9242 - val_loss: 0.6971 - val_accuracy: 0.8313
# Epoch 64/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.2102 - accuracy: 0.9214 - val_loss: 2.0188 - val_accuracy: 0.6073
# Epoch 65/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.2006 - accuracy: 0.9267 - val_loss: 0.6537 - val_accuracy: 0.8182
# Epoch 66/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1948 - accuracy: 0.9332 - val_loss: 1.3057 - val_accuracy: 0.6932
# Epoch 67/100
# 48/48 [==============================] - 134s 3s/step - loss: 0.2067 - accuracy: 0.9238 - val_loss: 2.1802 - val_accuracy: 0.5990
# Epoch 68/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.2048 - accuracy: 0.9269 - val_loss: 1.0455 - val_accuracy: 0.7573
# Epoch 69/100
# 48/48 [==============================] - 134s 3s/step - loss: 0.1965 - accuracy: 0.9319 - val_loss: 1.1011 - val_accuracy: 0.7406
# Epoch 70/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1693 - accuracy: 0.9397 - val_loss: 0.8089 - val_accuracy: 0.7953
# Epoch 71/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1795 - accuracy: 0.9354 - val_loss: 0.8836 - val_accuracy: 0.7828
# Epoch 72/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1844 - accuracy: 0.9318 - val_loss: 1.1760 - val_accuracy: 0.7104
# Epoch 73/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1784 - accuracy: 0.9389 - val_loss: 0.7566 - val_accuracy: 0.7969
# Epoch 74/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1865 - accuracy: 0.9382 - val_loss: 0.7453 - val_accuracy: 0.8130
# Epoch 75/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.1686 - accuracy: 0.9419 - val_loss: 0.5717 - val_accuracy: 0.8479
# Epoch 76/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1837 - accuracy: 0.9341 - val_loss: 0.9330 - val_accuracy: 0.7745
# Epoch 77/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1711 - accuracy: 0.9399 - val_loss: 0.8108 - val_accuracy: 0.7969
# Epoch 78/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1644 - accuracy: 0.9425 - val_loss: 0.7842 - val_accuracy: 0.8036
# Epoch 79/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1610 - accuracy: 0.9415 - val_loss: 1.1851 - val_accuracy: 0.7297
# Epoch 80/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1635 - accuracy: 0.9407 - val_loss: 0.7691 - val_accuracy: 0.7922
# Epoch 81/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1974 - accuracy: 0.9266 - val_loss: 0.5829 - val_accuracy: 0.8417
# Epoch 82/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1741 - accuracy: 0.9394 - val_loss: 0.7279 - val_accuracy: 0.7953
# Epoch 83/100
# 48/48 [==============================] - 129s 3s/step - loss: 0.1680 - accuracy: 0.9410 - val_loss: 0.7310 - val_accuracy: 0.8219
# Epoch 84/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1713 - accuracy: 0.9449 - val_loss: 1.4430 - val_accuracy: 0.6922
# Epoch 85/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1500 - accuracy: 0.9451 - val_loss: 1.7809 - val_accuracy: 0.6604
# Epoch 86/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1471 - accuracy: 0.9509 - val_loss: 0.9223 - val_accuracy: 0.7927
# Epoch 87/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1512 - accuracy: 0.9494 - val_loss: 0.7983 - val_accuracy: 0.8026
# Epoch 88/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1517 - accuracy: 0.9466 - val_loss: 1.4490 - val_accuracy: 0.7109
# Epoch 89/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1395 - accuracy: 0.9494 - val_loss: 0.8113 - val_accuracy: 0.7964
# Epoch 90/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1456 - accuracy: 0.9476 - val_loss: 1.7569 - val_accuracy: 0.6708
# Epoch 91/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.1448 - accuracy: 0.9515 - val_loss: 0.9205 - val_accuracy: 0.7719
# Epoch 92/100
# 48/48 [==============================] - 130s 3s/step - loss: 0.1491 - accuracy: 0.9509 - val_loss: 1.3715 - val_accuracy: 0.7156
# Epoch 93/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.1429 - accuracy: 0.9480 - val_loss: 1.6214 - val_accuracy: 0.6776
# Epoch 94/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1406 - accuracy: 0.9498 - val_loss: 0.9198 - val_accuracy: 0.7984
# Epoch 95/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1606 - accuracy: 0.9421 - val_loss: 1.1932 - val_accuracy: 0.7016
# Epoch 96/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1879 - accuracy: 0.9310 - val_loss: 1.6175 - val_accuracy: 0.6828
# Epoch 97/100
# 48/48 [==============================] - 132s 3s/step - loss: 0.1409 - accuracy: 0.9500 - val_loss: 0.8944 - val_accuracy: 0.7875
# Epoch 98/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1304 - accuracy: 0.9510 - val_loss: 1.5575 - val_accuracy: 0.6901
# Epoch 99/100
# 48/48 [==============================] - 131s 3s/step - loss: 0.1234 - accuracy: 0.9534 - val_loss: 1.0915 - val_accuracy: 0.7615
# Epoch 100/100
# 48/48 [==============================] - 133s 3s/step - loss: 0.1315 - accuracy: 0.9521 - val_loss: 1.8389 - val_accuracy: 0.6979

# %%
### save history
import pickle

# In case you want to create a checkpoint
with open('history.pickle', 'wb') as f:
    pickle.dump(history.history, f)
# In case you want to create a checkpoint
with open('history.pickle', 'rb') as f:
    history_ = pickle.load(f)
len(history_)
# Out:
# 5

# %%
### Plot loss and accuracy train, val
history = history_
epochs_ = len(history["loss"])
plt.style.use("ggplot")
plt.figure(figsize = (10, 5))
plt.plot(np.arange(0, epochs_), history["loss"], label="train_loss")
plt.plot(np.arange(0, epochs_), history["val_loss"], label="val_loss")
plt.title("Training & Validation Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.ylim(0, 3)
plt.show()

# %%
epochs_ = len(history["loss"])
plt.style.use("ggplot")
plt.figure(figsize = (10, 5))
plt.plot(np.arange(0, epochs_), history["accuracy"], label="train_acc")
plt.plot(np.arange(0, epochs_), history["val_accuracy"], label="val_acc")
plt.title("Training & Validation Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
model.save_weights(r'model_v1_weights.h5')
model.save(r'model_v1.h5')
